# %%
import io
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from psycopg2 import connect
from sqlalchemy import create_engine

# Creates the initial table for items purchased
# It is only needed for loading data for the first time
csv = "~/Desktop/items_purchased.csv"

def writeToPostgres(f):
    conn = connect("postgresql://tlapinskas@localhost/postgres")
    conn = connect("postgresql://INSERT-USERNAME@localhost/postgres")
    cursor = conn.cursor()
    cursor.execute('create table purchases (kiosk_id text, product_id text, card_hash text, date_time text, fc_number text);COMMIT; ')
    cursor.copy_from(f, 'purchases', columns=('kiosk_id', 'product_id', 'card_hash', 'date_time', 'fc_number'), sep='\t')
    cursor.close()

# Read columns
df = pd.read_csv(csv, usecols = ['kiosk_id', 'product_id', 'card_hash', 'date_time', 'fc_number'])

# Load data to temp CSV
f = io.StringIO()
df.to_csv(f, index=False, header=False, sep='\t')
f.seek(0)

# Load to Postgres
writeToPostgres(f)

print("Data load complete")
# Out:
# /usr/local/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning:
#
# The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
# Data load complete

# %%
# Loads data incrementally if format is the same as items_purchased.csv
# Use case: Hourly/Daily/Weekly load of items purchased data that needs to live in a Data Lake
csv = "/Users/tlapinskas/Desktop/items_purchased.csv"

conn = connect("postgresql://tlapinskas@localhost/postgres")
conn = connect("postgresql://INSERT-USERNAME@localhost/postgres")
cur = conn.cursor()
with open(csv, 'r') as f:
    # Notice that we don't need the `csv` module.
    next(f)  # Skip the header row.
    cur.copy_from(f, 'purchases', sep=',')
    
conn.commit()

cur.execute ('''SELECT COUNT(*) FROM purchases;''')
count = cur.fetchone()

print("Data load complete")
print ("Total records in purchases table:", count)
# Out:
# Data load complete
# Total Records: (2231144,)

# %%
# Creates the initial table for product information csv
# It is only needed for loading data for the first time
csv = "~/Desktop/product_info.csv"

def writeToPostgres(f):
    conn = connect("postgresql://tlapinskas@localhost/postgres")
    conn = connect("postgresql://INSERT-USERNAME@localhost/postgres")
    cursor = conn.cursor()
    cursor.execute('create table product_info (product_id text, product_name text, fc_number text, brand text, onqi text, cost text, margins text);COMMIT; ')
    cursor.copy_from(f, 'product_info', columns=('product_id', 'product_name', 'fc_number', 'brand', 'onqi', 'cost', 'margins'), sep='\t')
    cursor.close()

# Read columns
df = pd.read_csv(csv, usecols = ['product_id', 'product_name', 'fc_number', 'brand', 'onqi', 'cost', 'margins'])

# Load data to temp CSV
f = io.StringIO()
df.to_csv(f, index=False, header=False, sep='\t')
f.seek(0)

# Load to Postgres
writeToPostgres(f)

print("Data load complete")
# Out:
# Data load complete

# %%
# Loads data incrementally if format is the same as product_info.csv
# Use case: Hourly/Daily/Weekly load of items purchased data that needs to live in a Data Lake
csv = "/Users/tlapinskas/Desktop/product_info.csv"

conn = connect("postgresql://tlapinskas@localhost/postgres")
conn = connect("postgresql://INSERT-USERNAME@localhost/postgres")
cur = conn.cursor()
with open(csv, 'r') as f:
    # Notice that we don't need the `csv` module.
    next(f)  # Skip the header row.
    cur.copy_from(f, 'product_info', sep=',')
    
conn.commit()

cur.execute ('''SELECT COUNT(*) FROM product_info;''')
count = cur.fetchone()

print("Data load complete")
print ("Total records in product_info table:", count)

# %%
engine = create_engine("postgresql://tlapinskas@localhost/postgres")

# Grab data from Postgres
df = pd.read_sql('''
                    SELECT p.product_id, p.card_hash, pi.onqi
                    FROM purchases p, product_info pi
                    WHERE p.product_id = pi.product_id AND onqi > '50'
                    LIMIT 100;
                    ''', con=engine)
df = df.fillna('')

trace1 = go.Scatter(
    x=df['product_id'],
    y=df['onqi'],
    text=df['card_hash'],
    mode='markers'
)
layout = go.Layout(
    title='ONQI versus Card_Hash & Product_ID',
    xaxis=dict( type='log', title='PRODUCT_ID' ),
    yaxis=dict( title='ONQI' )
)
data = [trace1]
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='test')
# Out:
# <div id="69e49088-a2e4-48e9-979c-e42060e1c285" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("69e49088-a2e4-48e9-979c-e42060e1c285", [{"mode": "markers", "text": ["FEaD8IUmESlpzvPRYyZhMyUv/CRtDNIUyprR5w7e/mPkFzr/3Cvdcu2tj0u3jsOj0OUUfW2jhMhfwWM3iQI1Ig==", "N8JjRgpqKnQ8BDp+XtxBkfM0If/9GBL+rsOalHjHLdIM8Baf6tUC3UNDylqHc29iWnhr6/YT+RU63aZW2TXV6g==", "kzaHILrWFehUeo6gjZV1EwvZHNTXGNqTY/Hzv+mL9Bg+vRc+uuq4+C0hsm6nAI58FLfCtqhJFLT97zuOCng+Yw==", "4ox+j2exAB/xLlyHteKO/cNoSdLFb3T29mkacbTAf7ECiXy6L9/7hNFk4y4p/TjruzPmPFtYZNhxeLuNNwLgBg==", "hOB3nBlofMM/2khWcX9O2CoUZ4YyCFSXB6vbCowurdMCLl2hphPrsbCIzQT66E+uBlRYIyWIeI7TICUiCLrmfQ==", "aXKwvh3FKPQnAmhr/Xr7morkvOHFlNlNsWhodV07ih/3dnIgaXCYcDJNFS7Ovz5JRjzRv+ENFW7pQUMXKuDNyw==", "/LsTUZ9+kPu80yWAYUO1APGANmhfxUhw8RluKz/dB8EGY0Qg23tXWz1xNsoShznNR7rRasa7i52NQznT3n86JA==", "jixRoztZhEFkfdn5+0mXHsrTV0M4vsYezoEoaYkBFGVZPeenCmxQJnAbrMD/Tc4sjBflwKEL/cGBt2Sx59h6aw==", "jixRoztZhEFkfdn5+0mXHsrTV0M4vsYezoEoaYkBFGVZPeenCmxQJnAbrMD/Tc4sjBflwKEL/cGBt2Sx59h6aw==", "GikZBQIz8zSl/BQO1+v1sHcsD4FRSW5ou8kj23fXWp2ld1ANtdN1ip/GQYknEJpipom0sm9BekjhIhgYkUGXiQ==", "Z38Meh5obUMiGKdzbjRQSKUJFcrPr/6rDVB3IBQLa64OS1kzsSPR3yXdvjIRznt4LRfryUswTtxVKkLIki8vxA==", "evFBDWxj3Ns9KsbBOVdWPAxu9BSE4tHz/cwJB6prDFyHYbLJn4rLJ1DPhu0dKEAOmkcyJ1wQWhYC8vj0oa1hHw==", "AYDPrWLoqdxNicRuFKJmqSp8sKLiFa23MsI+5U1zGCLJ+Ko6nJtuakGVDWTMjYhgD5kvHsZlzzhg8TzANAnVWQ==", "AYDPrWLoqdxNicRuFKJmqSp8sKLiFa23MsI+5U1zGCLJ+Ko6nJtuakGVDWTMjYhgD5kvHsZlzzhg8TzANAnVWQ==", "0wt2JyUvA0FNEInIOtdNw4bHanolIiVozHlv/ttU+m9+gie1tjnqclyGRoswnyK35JEXcxiUOkww/clLNhGVQA==", "A1Rl0u+qdxAwuX2Kt8V8UxXwWz/Q5gr5KdALsvcyJmXlF1BrGB69bcNH74e0rz7dJ+MaWNh5kpC/jfjrke7Yhg==", "y3C7gV+41RPipeTayi9oYwhyupQv5ft/qckwpzheHiZ9IaoCb58/Q4ryq7/vkjfPz7ZF7mCmzi4qh1AhVrcSUA==", "fWEsWtFXNVUir7eIYyu3cqfEkaJFwHvGM2Ka2Viv9IveHAtuFirPEToCL+AloL4tnTIRXnADD2kABSTR/gStCQ==", "fThc6zEILsh/J6gM1vHFeFOYtt2wUdg3KBu3XtTigkmmBf6qOnBYeMO8lBw/wYhB2Ycv3XQFGrrWR/M25TnKzg==", "pFCsO21elMCmPzQ4S0ASZesbTnPjb75q6sB4KEwR/SHlZJ4XlKB3wssrWb1cTRVYjEraXRaQssMiFUKXjJ0r3Q==", "pFCsO21elMCmPzQ4S0ASZesbTnPjb75q6sB4KEwR/SHlZJ4XlKB3wssrWb1cTRVYjEraXRaQssMiFUKXjJ0r3Q==", "Pf7Qg+gs2pPPxn9CxRYkASRNtKAC/SfR7FdTIldUvXCBLEvrL5tB9g56888DOUrr7Aqe0X691RbnobFnrUa2Cw==", "5xeLjUx2IEK2v9BkuM1yJxOtPRH999Mi3tV4e8E3aoh56B23PDWJ8uV3XoLDt5Y/m2UI7hcr5ECdAYvFfNLBpQ==", "USiTEKIrwHKNJbj0m3PyneGUwrh+SkoCKK3okLev0Z2NZQmnwmYOlaM2Ib/o4i2LZv+0EApU879AnG7kLRaozQ==", "uIiIgJznYIYG7j8iKiHpXJKHhkioUaFvuxvssxje9nkEAFo/WM92eCM1Jx+JmFoj/vZysQ+KLfFSFlNJiqgTZQ==", "HDLcelOshvS1M95LiuAfvtKAsKjzUbk2+GMd8o2GGC/FXgS6Fg7prBJZt6aIv8srosa0srF8BV/oX9oJyMtAlQ==", "plvbNVFopw2DFslHMQZQ/kFxz5pJCI6FNu+50YHvnUHudV7pHz+4XdPpD6Thrqddb++p6j4UJbSU2OKWG4q4Aw==", "DSeocALyrt/59TOZ00UboEDz+oZdwzESZh8FXe/GtAKMWU+jOdVYxYtMV2ij/gKRIJ3C7xTFsqflr8ai/dqwOQ==", "GuDp4xuWzCHSd2nUQRq/0iFBLxheQNYyi0CsfccMBvfMY6O5+/1n8b9x5b47eDbnPKQL/a2tbN6TbqHqLLsujg==", "oHOy3w5lQlrj3F0dw9mtSVdT5LZnjw6uefz1DigTLBs8BfjVJOg2kT0XNxjNwkl36c/Fpy9qT/Uo6dBjMfvROg==", "qziZd6IiH4XyNUg9fiFnlFvzszXFfZ0xwj8D8yuJy/FYP0cPOc6QsHBDSC65txHMqGN0mpIffqTXiWhPmbu4Gw==", "PKEFq2ueAcm9ENP1+ar5HdmEgPUJBum2UIUDZWQ3t07wrevnqSKfbrgi+miQ4G9OFJXztEXrTjtnryLyBDmW5g==", "oubNuF/wLQs36Ziyp7/WsLL27nlbSPj4IkbtyTkrGsSOd622pznTuR0IzeY8OlUAYx8nylg/0RUGDhNBOc+NfA==", "iDSBQvz4d512d2ckK0Uf/+cw1RgHghfF6t+/YgO9/YAxSQzRsbesiKMkM222IGhH8szznXStZr/udym7+6ZZdQ==", "mvqlnyiysM3Gim5u1S7fbs8TwR9Ivv9WsxJcg6nHDmSKip1Ib7DSRMgge1+uYpDDhg1UIIpwqW6t1pb5Nc6DcQ==", "Z38Meh5obUMiGKdzbjRQSKUJFcrPr/6rDVB3IBQLa64OS1kzsSPR3yXdvjIRznt4LRfryUswTtxVKkLIki8vxA==", "qL54WOh17aMH0sDhdkYHVQ3opqpwxAnu6MIqm5c1tlJFP82Fp9TzR0lpSTI7QRjwG2lOH25L5ZI2ufsBTwdgUA==", "tirRemnz/6MitRMoVQ+nRPAZI5CSEIibkJUMBMHXWIapcsX9rG8iHe+6vgGH/Wnzu+fzeGPuhsiUlv2I3bCRBQ==", "OAon1kBbmQQW33MqKsLzgVg/NA337/pJDTPN/nZplkU55T5KjikAUEm5OuqnqvY4fev70FzwODIxi0NFYOvlGA==", "Cq6FnhhgjXUHg9GttM8PS4mz4Hy6rWviVjfef6jUmdW//q8MeKC3ehW4eB ...
